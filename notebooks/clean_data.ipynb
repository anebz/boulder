# %%
import pandas as pd

# %%
boulder_data = pd.read_csv("~/Desktop/coding/boulder_data/boulderdata.csv")

# %%
boulder_data.head()
# Out:
#         gym_name      current_time  occupancy  waiting  weather_temp  \
# 0      frankfurt  2020/10/29 18:31       61.0      0.0         10.95
# 1  muenchen-west  2020/10/29 18:31       27.0      0.0          9.22
# 2   muenchen-ost  2020/10/29 18:31      100.0     14.0          9.22
# 3       dortmund  2020/10/29 18:31       56.0      0.0         10.00
# 4     regensburg  2020/10/29 18:31       68.0      0.0          7.42
#
#   weather_status
# 0           Rain
# 1           Rain
# 2           Rain
# 3           Rain
# 4           Rain

# %% [markdown]
# ##  Delete rows at night (current_time before 7:00, and after 23:00)

# %%
boulder_data['current_time'].describe()
# Out:
# count                56784
# unique               10867
# top       2020/10/29 18:01
# freq                    15
# Name: current_time, dtype: object

# %%
boulder_data.head(100)
# Out:
#          gym_name      current_time  occupancy  waiting  weather_temp  \
# 0       frankfurt  2020/10/29 18:31       61.0      0.0         10.95
# 1   muenchen-west  2020/10/29 18:31       27.0      0.0          9.22
# 2    muenchen-ost  2020/10/29 18:31      100.0     14.0          9.22
# 3        dortmund  2020/10/29 18:31       56.0      0.0         10.00
# 4      regensburg  2020/10/29 18:31       68.0      0.0          7.42
# ..            ...               ...        ...      ...           ...
# 95   muenchen-ost  29/10/2020 16:31       91.0      0.0          8.97
# 96  muenchen-west  29/10/2020 16:31       27.0      0.0          8.97
# 97      frankfurt  29/10/2020 16:31       50.0      0.0         10.75
# 98     regensburg  29/10/2020 16:31       68.0      0.0          7.16
# 99       dortmund  29/10/2020 16:31       11.0      0.0         10.00
#
#    weather_status
# 0            Rain
# 1            Rain
# 2            Rain
# 3            Rain
# 4            Rain
# ..            ...
# 95           Rain
# 96           Rain
# 97           Rain
# 98           Rain
# 99           Rain
#
# [100 rows x 6 columns]

# %%
closed_times = ['23:', '00:', '01:', '02:', '03:', '04:', '05:', '06:']

for i in closed_times:
    boulder_data = boulder_data[~boulder_data.current_time.str.contains(i)]

# %%
boulder_data['current_time'].describe()
# Out:
# count                38587
# unique                7377
# top       2020/10/29 18:16
# freq                    15
# Name: current_time, dtype: object

# %% [markdown]
# ##  Delete rows where minute is not in 00, 15, 30 or 45

# %%
data1 = boulder_data.loc[boulder_data['current_time'].str.contains(":00")]
data2 = boulder_data.loc[boulder_data['current_time'].str.contains(":15")]
data3 = boulder_data.loc[boulder_data['current_time'].str.contains(":30")]
data4 = boulder_data.loc[boulder_data['current_time'].str.contains(":45")]

# %%
data1.head(10)
# Out:
#           gym_name      current_time  occupancy  waiting  weather_temp  \
# 80      regensburg  2020/10/29 17:00       68.0      0.0          7.42
# 81   muenchen-west  2020/10/29 17:00       27.0      0.0          9.09
# 82       frankfurt  2020/10/29 17:00       59.0      0.0         10.75
# 83        dortmund  2020/10/29 17:00       11.0      0.0          9.99
# 84    muenchen-ost  2020/10/29 17:00      100.0     14.0          9.09
# 125  muenchen-west  29/10/2020 15:00       27.0      0.0          9.36
# 126     regensburg  29/10/2020 15:00       68.0      0.0          7.84
# 127   muenchen-ost  29/10/2020 15:00       80.0      0.0          9.36
# 128       dortmund  29/10/2020 15:00       11.0      0.0         11.35
# 129      frankfurt  29/10/2020 15:00       22.0      0.0         10.79
#
#     weather_status
# 80            Rain
# 81            Rain
# 82            Rain
# 83            Rain
# 84            Rain
# 125           Rain
# 126           Rain
# 127           Rain
# 128           Rain
# 129           Rain

# %%
data2.head(10)
# Out:
#            gym_name      current_time  occupancy  waiting  weather_temp  \
# 22760  muenchen-ost  2020/09/26 09:15       97.0      0.0          7.06
# 22761      dortmund  2020/09/26 09:15       32.0      0.0         10.57
# 22762     frankfurt  2020/09/26 09:15       54.0      0.0          9.75
# 22763    regensburg  2020/09/26 09:15       42.0      0.0          7.57
# 25782           ost  2020/09/22 07:15       44.0      0.0         14.26
# 25783      dortmund  2020/09/22 07:15        7.0      0.0         14.09
# 25784     frankfurt  2020/09/22 07:15        0.0      0.0         13.08
# 27959      dortmund  2020/09/21 22:15        0.0      0.0         15.21
# 27960          west  2020/09/21 22:15        0.0      0.0         13.79
# 27961    regensburg  2020/09/21 22:15        0.0      0.0         12.99
#
#       weather_status
# 22760           Rain
# 22761         Clouds
# 22762         Clouds
# 22763         Clouds
# 25782          Clear
# 25783          Clear
# 25784          Clear
# 27959          Clear
# 27960         Clouds
# 27961         Clouds

# %%
boulder_data = boulder_data.loc[(boulder_data['current_time'].str.contains(":00")) | (boulder_data['current_time'].str.contains(":15")) | (boulder_data['current_time'].str.contains(":30")) | (boulder_data['current_time'].str.contains(":45"))]

# %%
boulder_data['current_time'].describe()
# Out:
# count                 1984
# unique                 404
# top       2020/10/22 07:00
# freq                    10
# Name: current_time, dtype: object
